# %% [markdown]
# ## Install obspy
#
# Remember to click "Runtime" then "Restart runtime", otherwise obspy may report some error.
#
# See details in this [issue](https://github.com/obspy/obspy/issues/2547)
#
# Note: Please only use the QuakeFlow API for debugging and testing on small datasets. Do not run large jobs using the QuakeFlow API. The computational cost can be high for us.

# %%
try:
    import obspy
except:
    # !pip install obspy

# %%
from collections import defaultdict
import numpy as np
import pandas as pd
import time
import requests
import json
import obspy
from obspy.clients.fdsn import Client

# from google.colab import data_table
# data_table.enable_dataframe_formatter()

# %% [markdown]
# ## 1. Configuration

# %%
region_name = "Indonesia_demo"
center = (107.67, -7.19)  # Koordinat pusat Indonesia
horizontal_degree = 50.0  # Jangkauan horizontal dalam derajat
vertical_degree = 50.0  # Jangkauan vertikal dalam derajat
starttime = obspy.UTCDateTime("2024-09-18T02:00:00")
endtime = obspy.UTCDateTime("2024-09-18T03:00:00")
client = "http://geofon.gfz-potsdam.de"  # Client untuk data seismik
network_list = ["GE"]  # Contoh jaringan internasional di Indonesia
channel_list = "BHZ, BHN, BHE"  # Daftar kanal umum untuk stasiun geofon

config = {}
config["region"] = region_name
config["center"] = center
config["xlim_degree"] = [center[0] - horizontal_degree / 2, center[0] + horizontal_degree / 2]
config["ylim_degree"] = [center[1] - vertical_degree / 2, center[1] + vertical_degree / 2]
config["starttime"] = starttime.datetime.isoformat()
config["endtime"] = endtime.datetime.isoformat()
config["networks"] = network_list
config["channels"] = channel_list
config["client"] = client

# %% [markdown]
# ## 2. Download event information

# %%
events = Client("IRIS").get_events(
    starttime=config["starttime"],
    endtime=config["endtime"],
    minlongitude=config["xlim_degree"][0],
    maxlongitude=config["xlim_degree"][1],
    minlatitude=config["ylim_degree"][0],
    maxlatitude=config["ylim_degree"][1],
)

# %%
events[0]["origins"][0].time
# Out:
# 2024-09-18T02:41:06.667000Z

# %% [markdown]
# ## 3. Download station information

# %%
stations = Client(config["client"]).get_stations(
    network=",".join(config["networks"]),
    station="*",
    starttime=config["starttime"],
    endtime=config["endtime"],
    minlongitude=config["xlim_degree"][0],
    maxlongitude=config["xlim_degree"][1],
    minlatitude=config["ylim_degree"][0],
    maxlatitude=config["ylim_degree"][1],
    channel=config["channels"],
    level="response",
)

# %%
stations
# Out:
# Inventory created at 2024-12-16T15:26:41.177635Z
# 	Sending institution: SeisComP (GFZ)
# 	Contains:
# 		Networks (1):
# 			GE
# 		Stations (20):
# 			GE.BBJI (GEOFON Station GEOFON Station Bungbulang, Garut, Java)
# 			GE.BKB (GEOFON Station GEOFON Station Balikpapan, Kalimantan)
# 			GE.BKNI (GEOFON Station GEOFON Station Bangkinang, Sumatra)
# 			GE.BNDI (GEOFON Station Bandaneira, Indonesia)
# 			GE.FAKI (GEOFON Station GEOFON Station Fak Fak, Irian Jaya)
# 			GE.GSI (GEOFON Station Gunungsitoli, Nias)
# 			GE.JAGI (GEOFON Station GEOFON Station Jajag, Java)
# 			GE.LHMI (GEOFON Station GEOFON Station Lhokseumave, Sumatra)
# 			GE.LUWI (GEOFON Station GEOFON Station Lhokseumave, Sulawesi)
# 			GE.MMRI (GEOFON Station GEOFON Station Maumere, Flores)
# 			GE.MNAI (GEOFON Station GEOFON Station Manna, Sumatra)
# 			GE.PLAI (GEOFON Station Plampang, Sumbawa, Indonesia)
# 			GE.PMBI (GEOFON Station Palembang, Sumatra)
# 			GE.SANI (GEOFON Station Sanana, Moluccas, Indonesia)
# 			GE.SAUI (GEOFON Station Saumlaki, Tanimbar, Indonesia)
# 			GE.SMRI (GEOFON Station GEOFON Station Semarang, Java)
# 			GE.SOEI (GEOFON Station GEOFON Station Soe, Timor)
# 			GE.TNTI (GEOFON Station GEOFON Station Ternate, Indonesia)
# 			GE.TOLI2 (GEOFON Station Tolitoli, Sulawesi, Indonesia)
# 			GE.UGM (GEOFON Station Wanagama, Indonesia)
# 		Channels (60):
# 			GE.BBJI..BHZ, GE.BBJI..BHN, GE.BBJI..BHE, GE.BKB..BHZ, GE.BKB..BHN
# 			GE.BKB..BHE, GE.BKNI..BHZ, GE.BKNI..BHN, GE.BKNI..BHE,
# 			GE.BNDI..BHZ, GE.BNDI..BHN, GE.BNDI..BHE, GE.FAKI..BHZ,
# 			GE.FAKI..BHN, GE.FAKI..BHE, GE.GSI..BHZ, GE.GSI..BHN, GE.GSI..BHE,
# 			GE.JAGI..BHZ, GE.JAGI..BHN, GE.JAGI..BHE, GE.LHMI..BHZ,
# 			GE.LHMI..BHN, GE.LHMI..BHE, GE.LUWI..BHZ, GE.LUWI..BHN,
# 			GE.LUWI..BHE, GE.MMRI..BHZ, GE.MMRI..BHN, GE.MMRI..BHE,
# 			GE.MNAI..BHZ, GE.MNAI..BHN, GE.MNAI..BHE, GE.PLAI..BHZ,
# 			GE.PLAI..BHN, GE.PLAI..BHE, GE.PMBI..BHZ, GE.PMBI..BHN,
# 			GE.PMBI..BHE, GE.SANI..BHZ, GE.SANI..BHN, GE.SANI..BHE,
# 			GE.SAUI..BHZ, GE.SAUI..BHN, GE.SAUI..BHE, GE.SMRI..BHZ,
# 			GE.SMRI..BHN, GE.SMRI..BHE, GE.SOEI..BHZ, GE.SOEI..BHN,
# 			GE.SOEI..BHE, GE.TNTI..BHZ, GE.TNTI..BHN, GE.TNTI..BHE,
# 			GE.TOLI2..BHZ, GE.TOLI2..BHN, GE.TOLI2..BHE, GE.UGM..BHZ,
# 			GE.UGM..BHN, GE.UGM..BHE

# %% [markdown]
# ## 3.1 Convert station information into csv

# %%
station_locs = defaultdict(dict)
for network in stations:
    for station in network:
        for chn in station:
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation_m"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict

station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["station_id"] = station_locs.index

# %% [markdown]
# ## 4. Download waveform

# %%
client = Client(config["client"])
interval = 3600 #s
# interval = 3600 #s
interval_start = 60

# for event in events:
def downlad(event, stations):
    starttime = event["origins"][0].time
    endtime = starttime + interval

    max_retry = 20
    stream = obspy.Stream()
    num_sta = 0
    for network in stations:
        for station in network:
            print(f"********{network.code}.{station.code}********")
            retry = 0
            while retry < max_retry:
                try:
                    tmp = client.get_waveforms(
                        network.code, station.code, "*", config["channels"], starttime, endtime
                    )
                    for trace in tmp:
                        if trace.stats.sampling_rate != 100:
                            # print(trace)
                            trace = trace.interpolate(100, method="linear")
                    #      trace = trace.detrend("spline", order=2, dspline=5*trace.stats.sampling_rate)
                    #      stream.append(trace)
                    stream += tmp
                    num_sta += len(tmp)
                    break
                except Exception as err:
                    print("Error {}.{}: {}".format(network.code, station.code, err))
                    message = "No data available for request."
                    if str(err)[: len(message)] == message:
                        break
                    retry += 1
                    time.sleep(5)
                    continue
            if retry == max_retry:
                print(f"{station.code}: MAX {max_retry} retries reached : {network.code}.{station.code}")

    # stream.attach_response(stations)
    # stream = stream.remove_sensitivity()
    return stream

# %%
mseed = downlad(events[0], stations)
# Out:
# ********GE.BBJI********
# ********GE.BKB********
# ********GE.BKNI********
# Error GE.BKNI: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# ********GE.BNDI********
# ********GE.FAKI********
# ********GE.GSI********
# ********GE.JAGI********
# ********GE.LHMI********
# ********GE.LUWI********
# ********GE.MMRI********
# ********GE.MNAI********
# ********GE.PLAI********
# ********GE.PMBI********
# ********GE.SANI********
# ********GE.SAUI********
# Error GE.SAUI: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
#
#
# ********GE.SMRI********
# ********GE.SOEI********
# ********GE.TNTI********
# ********GE.TOLI2********
# ********GE.UGM********
# Error GE.UGM: No data available for request.
# HTTP Status code: 204
# Detailed response of server:

# %% [markdown]
# ## 5. Convert waveform to numpy

# %%
sampling_rate = 100
n_channel = 3
dtype = "float32"
amplitude = True
remove_resp = True

def convert_mseed(mseed, station_locs):
    try:
        mseed = mseed.detrend("spline", order=2, dspline=5 * mseed[0].stats.sampling_rate)
    except:
        logging.error(f"Error: spline detrend failed at file {fname}")
        mseed = mseed.detrend("demean")
    mseed = mseed.merge(fill_value=0)
    starttime = min([st.stats.starttime for st in mseed])
    endtime = max([st.stats.endtime for st in mseed])
    mseed = mseed.trim(starttime, endtime, pad=True, fill_value=0)

    for i in range(len(mseed)):
        if mseed[i].stats.sampling_rate != sampling_rate:
            logging.warning(
                f"Resampling {mseed[i].id} from {mseed[i].stats.sampling_rate} to {sampling_rate} Hz"
            )
            mseed[i] = mseed[i].interpolate(sampling_rate, method="linear")

    order = ['3', '2', '1', 'E', 'N', 'Z']
    order = {key: i for i, key in enumerate(order)}
    comp2idx = {"3": 0, "2": 1, "1": 2, "E": 0, "N": 1, "Z": 2}

    nsta = len(station_locs)
    nt = max(len(mseed[i].data) for i in range(len(mseed)))
    data = []
    station_id = []
    t0 = []
    for i in range(nsta):
        trace_data = np.zeros([nt, n_channel], dtype=dtype)
        empty_station = True
        # sta = station_locs.iloc[i]["station"]
        sta = station_locs.index[i]
        comp = station_locs.iloc[i]["component"].split(",")
        if remove_resp:
            resp = station_locs.iloc[i]["response"].split(",")
            # resp = station_locs.iloc[i]["response"]

        for j, c in enumerate(sorted(comp, key=lambda x: order[x[-1]])):

            resp_j = float(resp[j])
            if len(comp) != 3:  ## less than 3 component
                j = comp2idx[c]

            if len(mseed.select(id=sta + c)) == 0:
                print(f"Empty trace: {sta+c} {starttime}")
                continue
            else:
                empty_station = False

            tmp = mseed.select(id=sta + c)[0].data.astype(dtype)
            trace_data[: len(tmp), j] = tmp[:nt]

            if station_locs.iloc[i]["unit"] == "m/s**2":
                tmp = mseed.select(id=sta + c)[0]
                tmp = tmp.integrate()
                tmp = tmp.filter("highpass", freq=1.0)
                tmp = tmp.data.astype(dtype)
                trace_data[: len(tmp), j] = tmp[:nt]
            elif station_locs.iloc[i]["unit"] == "m/s":
                tmp = mseed.select(id=sta + c)[0].data.astype(dtype)
                trace_data[: len(tmp), j] = tmp[:nt]
            else:
                print(
                    f"Error in {station_locs.iloc[i]['station']}\n{station_locs.iloc[i]['unit']} should be m/s**2 or m/s!"
                )

            if remove_resp:
                trace_data[:, j] /= resp_j

        if not empty_station:
            data.append(trace_data)
            station_id.append(sta)
            t0.append(starttime.strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3])

    data = np.stack(data)

    meta = {"data": data, "t0": t0, "station_id": station_id, "fname": station_id}


    return meta

# %%
meta = convert_mseed(mseed, station_locs)
# Out:
# Empty trace: GE.BKNI..BHE 2024-09-18T02:41:06.669536Z
# Empty trace: GE.BKNI..BHN 2024-09-18T02:41:06.669536Z
# Empty trace: GE.BKNI..BHZ 2024-09-18T02:41:06.669536Z
# Empty trace: GE.SAUI..BHE 2024-09-18T02:41:06.669536Z
# Empty trace: GE.SAUI..BHN 2024-09-18T02:41:06.669536Z
# Empty trace: GE.SAUI..BHZ 2024-09-18T02:41:06.669536Z
# Empty trace: GE.UGM..BHE 2024-09-18T02:41:06.669536Z
# Empty trace: GE.UGM..BHN 2024-09-18T02:41:06.669536Z
# Empty trace: GE.UGM..BHZ 2024-09-18T02:41:06.669536Z

# %% [markdown]
# ## 6. Pick P/S picks using PhaseNet

# %%
PHASENET_API_URL = "http://34.30.199.8:8000"

batch = 4
phasenet_picks = []
for j in range(0, len(meta["station_id"]), batch):
    req = {"id": meta['station_id'][j:j+batch],
        "timestamp": meta["t0"][j:j+batch],
        "vec": meta["data"][j:j+batch].tolist()}

# print(meta["data"][0])

    resp = requests.post(f'{PHASENET_API_URL}/predict', json=req)
    print(resp.status_code)
    print(resp.text)

    phasenet_picks.extend(resp.json())

print('PhaseNet picks', pd.DataFrame(phasenet_picks))
# Out:
# 200
# [{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:41:12.889","phase_score":0.842,"phase_type":"P","dt":0.01,"phase_amplitude":0.005412620026618242},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:43:52.929","phase_score":0.433,"phase_type":"P","dt":0.01,"phase_amplitude":6.37675475445576e-05},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:45:27.619","phase_score":0.899,"phase_type":"P","dt":0.01,"phase_amplitude":1.3554576071328484e-05},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:46:39.539","phase_score":0.836,"phase_type":"P","dt":0.01,"phase_amplitude":1.0399807251815218e-05},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:47:40.049","phase_score":0.728,"phase_type":"P","dt":0.01,"phase_amplitude":3.3307564990536775e-06},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:48:26.449","phase_score":0.901,"phase_type":"P","dt":0.01,"phase_amplitude":9.718434739625081e-05},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:49:41.219","phase_score":0.825,"phase_type":"P","dt":0.01,"phase_amplitude":2.2399112822313327e-06},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:49:54.539","phase_score":0.332,"phase_type":"P","dt":0.01,"phase_amplitude":3.0940354918129742e-06},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:50:46.929","phase_score":0.757,"phase_type":"P","dt":0.01,"phase_amplitude":1.986181359825423e-06},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02:51:25.369","phase_score":0.753,"phase_type":"P","dt":0.01,"phase_amplitude":5.086860710434848e-07},{"station_id":"GE.BBJI..BH","phase_time":"2024-09-18T02
-07},{"station_id":"GE.TOLI2..BH","phase_time":"2024-09-18T03:23:40.269","phase_score":0.485,"phase_type":"S","dt":0.01,"phase_amplitude":2.4677399323991267e-07},{"station_id":"GE.TOLI2..BH","phase_time":"2024-09-18T03:23:48.169","phase_score":0.335,"phase_type":"S","dt":0.01,"phase_amplitude":1.93381154645067e-07},{"station_id":"GE.TOLI2..BH","phase_time":"2024-09-18T03:32:25.809","phase_score":0.323,"phase_type":"S","dt":0.01,"phase_amplitude":2.6526601004661643e-07}]
# PhaseNet picks        station_id               phase_time  phase_score phase_type    dt  \
# 0     GE.BBJI..BH  2024-09-18T02:41:12.889        0.842          P  0.01
# 1     GE.BBJI..BH  2024-09-18T02:43:52.929        0.433          P  0.01
# 2     GE.BBJI..BH  2024-09-18T02:45:27.619        0.899          P  0.01
# 3     GE.BBJI..BH  2024-09-18T02:46:39.539        0.836          P  0.01
# 4     GE.BBJI..BH  2024-09-18T02:47:40.049        0.728          P  0.01
# ..            ...                      ...          ...        ...   ...
# 237  GE.TOLI2..BH  2024-09-18T03:21:56.669        0.505          S  0.01
# 238  GE.TOLI2..BH  2024-09-18T03:22:48.589        0.547          S  0.01
# 239  GE.TOLI2..BH  2024-09-18T03:23:40.269        0.485          S  0.01
# 240  GE.TOLI2..BH  2024-09-18T03:23:48.169        0.335          S  0.01
# 241  GE.TOLI2..BH  2024-09-18T03:32:25.809        0.323          S  0.01
#
#      phase_amplitude
# 0       5.412620e-03
# 1       6.376755e-05
# 2       1.355458e-05
# 3       1.039981e-05
# 4       3.330756e-06
# ..               ...
# 237     2.172834e-07
# 238     3.097030e-07
# 239     2.467740e-07
# 240     1.933812e-07
# 241     2.652660e-07
#
# [242 rows x 6 columns]

# %%
pd.DataFrame(phasenet_picks)
# Out:
#        station_id               phase_time  phase_score phase_type    dt  \
# 0     GE.BBJI..BH  2024-09-18T02:41:12.889        0.842          P  0.01
# 1     GE.BBJI..BH  2024-09-18T02:43:52.929        0.433          P  0.01
# 2     GE.BBJI..BH  2024-09-18T02:45:27.619        0.899          P  0.01
# 3     GE.BBJI..BH  2024-09-18T02:46:39.539        0.836          P  0.01
# 4     GE.BBJI..BH  2024-09-18T02:47:40.049        0.728          P  0.01
# ..            ...                      ...          ...        ...   ...
# 237  GE.TOLI2..BH  2024-09-18T03:21:56.669        0.505          S  0.01
# 238  GE.TOLI2..BH  2024-09-18T03:22:48.589        0.547          S  0.01
# 239  GE.TOLI2..BH  2024-09-18T03:23:40.269        0.485          S  0.01
# 240  GE.TOLI2..BH  2024-09-18T03:23:48.169        0.335          S  0.01
# 241  GE.TOLI2..BH  2024-09-18T03:32:25.809        0.323          S  0.01
#
#      phase_amplitude
# 0       5.412620e-03
# 1       6.376755e-05
# 2       1.355458e-05
# 3       1.039981e-05
# 4       3.330756e-06
# ..               ...
# 237     2.172834e-07
# 238     3.097030e-07
# 239     2.467740e-07
# 240     1.933812e-07
# 241     2.652660e-07
#
# [242 rows x 6 columns]

# %%
# prompt: export phasenet_picks to excel

import pandas as pd

# Assuming 'phasenet_picks' is already defined from the previous code

# Create a Pandas DataFrame from the phasenet_picks list
phasenet_df = pd.DataFrame(phasenet_picks)

# Export the DataFrame to an Excel file
phasenet_df.to_excel("phasenet_picks.xlsx", index=False)

# %%
type([meta['station_id'][j:j+batch]])
# Out:
# list

# %%
meta["t0"][j:j+batch]
# Out:
# ['2024-09-18T02:41:06.669']

# %%
meta["data"][j:j+batch].shape
# Out:
# (1, 360001, 3)

# %%
stations_json = station_locs.to_dict(orient="records")

# %%
stations_json
# Out:
# [{'longitude': 107.65,
#   'latitude': -7.462603,
#   'elevation_m': 615.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.BBJI..BH'},
#  {'longitude': 116.9048,
#   'latitude': -1.1073,
#   'elevation_m': 110.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.BKB..BH'},
#  {'longitude': 101.0396,
#   'latitude': 0.3262,
#   'elevation_m': 65.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.BKNI..BH'},
#  {'longitude': 129.9045,
#   'latitude': -4.5224,
#   'elevation_m': 16.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.BNDI..BH'},
#  {'longitude': 132.24889,
#   'latitude': -2.91925,
#   'elevation_m': 136.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.FAKI..BH'},
#  {'longitude': 97.5755,
#   'latitude': 1.3039,
#   'elevation_m': 107.0,
#   'component': 'Z,N,E',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.GSI..BH'},
#  {'longitude': 114.1521,
#   'latitude': -8.4702,
#   'elevation_m': 171.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.JAGI..BH'},
#  {'longitude': 96.9472,
#   'latitude': 5.2288,
#   'elevation_m': 3.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.LHMI..BH'},
#  {'longitude': 122.7717,
#   'latitude': -1.0418,
#   'elevation_m': 6.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.LUWI..BH'},
#  {'longitude': 122.2376,
#   'latitude': -8.6357,
#   'elevation_m': 137.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.MMRI..BH'},
#  {'longitude': 102.9557,
#   'latitude': -4.3605,
#   'elevation_m': 154.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.MNAI..BH'},
#  {'longitude': 117.7765,
#   'latitude': -8.8275,
#   'elevation_m': 125.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.PLAI..BH'},
#  {'longitude': 104.6993,
#   'latitude': -2.9024,
#   'elevation_m': 25.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.PMBI..BH'},
#  {'longitude': 125.9881,
#   'latitude': -2.0496,
#   'elevation_m': 30.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.SANI..BH'},
#  {'longitude': 131.2988,
#   'latitude': -7.9826,
#   'elevation_m': 110.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.SAUI..BH'},
#  {'longitude': 110.44067,
#   'latitude': -7.04915,
#   'elevation_m': 203.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.SMRI..BH'},
#  {'longitude': 124.2672,
#   'latitude': -9.7553,
#   'elevation_m': 1047.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.SOEI..BH'},
#  {'longitude': 127.3667,
#   'latitude': 0.7718,
#   'elevation_m': 43.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.TNTI..BH'},
#  {'longitude': 120.78174,
#   'latitude': 1.11119,
#   'elevation_m': 51.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.TOLI2..BH'},
#  {'longitude': 110.5231,
#   'latitude': -7.9125,
#   'elevation_m': 350.0,
#   'component': 'N,E,Z',
#   'response': '629145000.00,629145000.00,629145000.00',
#   'unit': 'm/s',
#   'station_id': 'GE.UGM..BH'}]

# %%
phasenet_picks
# Out:
# [{'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:41:12.889',
#   'phase_score': 0.842,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 0.005412620026618242},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:43:52.929',
#   'phase_score': 0.433,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.37675475445576e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:45:27.619',
#   'phase_score': 0.899,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.3554576071328484e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:39.539',
#   'phase_score': 0.836,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0399807251815218e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:40.049',
#   'phase_score': 0.728,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.3307564990536775e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:48:26.449',
#   'phase_score': 0.901,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.718434739625081e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49

#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.738500709005166e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:32:24.779',
#   'phase_score': 0.876,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.994922164769378e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:05.079',
#   'phase_score': 0.95,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.326463335426524e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:33.039',
#   'phase_score': 0.912,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 7.879752388362249e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:38:05.209',
#   'phase_score': 0.908,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.1064905720559182e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:38:58.209',
#   'phase_score': 0.378,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.954094035587332e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:41:16.859',
#   'phase_score': 0.762,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 0.005412620026618242},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:43:56.849',
#   'phase_score': 0.345,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.748487819801085e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:45:31.479',
#   'phase_score': 0.675,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1955237823713105e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:47.849',
#   'phase_score': 0.492,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0399807251815218e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:55.729',
#   'phase_score': 0.537,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.747132036049152e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:46.529',
#   'phase_score': 0.402,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.7154663914407138e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:55.659',
#   'phase_score': 0.667,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.773294782964513e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:48:30.529',
#   'phase_score': 0.899,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.718434739625081e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:45.149',
#   'phase_score': 0.792,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.548115389799932e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:58.669',
#   'phase_score': 0.498,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.779884425763157e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:50:50.699',
#   'phase_score': 0.821,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.986181359825423e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:31.219',
#   'phase_score': 0.837,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.353004790871637e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:42.289',
#   'phase_score': 0.331,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.198167751681467e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:54.369',
#   'phase_score': 0.347,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0836748742804048e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:36.579',
#   'phase_score': 0.76,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1247284419368953e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:45.259',
#   'phase_score': 0.891,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.218093297618907e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:53:23.069',
#   'phase_score': 0.896,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.573756086756475e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:04.939',
#   'phase_score': 0.876,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.6460057799558854e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:18.829',
#   'phase_score': 0.901,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.9630234621436102e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:12.679',
#   'phase_score': 0.812,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.614198006602237e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:35.099',
#   'phase_score': 0.754,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.560805102002632e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:52.669',
#   'phase_score': 0.616,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.038408741915191e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:56:50.299',
#   'phase_score': 0.86,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.270209382819303e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:04.679',
#   'phase_score': 0.481,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.07962704179954e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:17.019',
#   'phase_score': 0.723,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.734748118717107e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:27.199',
#   'phase_score': 0.806,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.024310543281899e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:45.829',
#   'phase_score': 0.855,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.4976864046475384e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:28.789',
#   'phase_score': 0.821,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.58664976072032e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:47.239',
#   'phase_score': 0.411,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.3000269518670393e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:59:35.399',
#   'phase_score': 0.736,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.347796102090797e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:00:41.639',
#   'phase_score': 0.605,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.853510742781509e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:11.819',
#   'phase_score': 0.834,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.890335056486947e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:36.779',
#   'phase_score': 0.768,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0529754490562482e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:51.989',
#   'phase_score': 0.925,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.302953584556235e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:02:32.499',
#   'phase_score': 0.649,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.139616743894294e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:02:48.689',
#   'phase_score': 0.542,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.605399226420559e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:16.219',
#   'phase_score': 0.743,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.50868059892673e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:43.399',
#   'phase_score': 0.863,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.379987442211132e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:52.509',
#   'phase_score': 0.807,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.174525992719282e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:04:05.569',
#   'phase_score': 0.351,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.006190235690156e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:05:27.989',
#   'phase_score': 0.87,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.046306442731293e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:06:41.499',
#   'phase_score': 0.903,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.033222012367332e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:07:55.479',
#   'phase_score': 0.82,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.22520303750207e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:26.979',
#   'phase_score': 0.852,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.73854192048384e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:46.449',
#   'phase_score': 0.436,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.620011620521836e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:59.789',
#   'phase_score': 0.504,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.7661628817222663e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:09:13.069',
#   'phase_score': 0.553,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.714769930724287e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:10:22.689',
#   'phase_score': 0.358,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.4472716353993746e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03
-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:00:40.139',
#   'phase_score': 0.379,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.1638705050008866e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:04:54.049',
#   'phase_score': 0.558,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.194143403106864e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:06.009',
#   'phase_score': 0.609,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.146691938127333e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:42.949',
#   'phase_score': 0.31,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.961456289085618e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:48.099',
#   'phase_score': 0.697,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.588195968655782e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:38:39.859',
#   'phase_score': 0.317,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.592032330994698e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:49:44.689',
#   'phase_score': 0.411,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.3119167142103834e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:59:13.579',
#   'phase_score': 0.405,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.587345531741448e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:01:59.559',
#   'phase_score': 0.361,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.4192712544390815e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:04:58.759',
#   'phase_score': 0.766,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.194143403106864e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:47.719',
#   'phase_score': 0.546,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.961456289085618e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:11:43.249',
#   'phase_score': 0.386,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1181214176758658e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:11:43.889',
#   'phase_score': 0.462,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.479090426277253e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:12:52.049',
#   'phase_score': 0.648,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.2371450825175998e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:08.909',
#   'phase_score': 0.689,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.5661390168352227e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:14.449',
#   'phase_score': 0.306,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.453284366765729e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:51.859',
#   'phase_score': 0.648,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.5939044689948787e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:21:56.669',
#   'phase_score': 0.505,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.1728338595039531e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:22:48.589',
#   'phase_score': 0.547,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.0970304010224936e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:23:40.269',
#   'phase_score': 0.485,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.4677399323991267e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:23:48.169',
#   'phase_score': 0.335,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.93381154645067e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:32:25.809',
#   'phase_score': 0.323,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.6526601004661643e-07}]

# %%
picks = pd.DataFrame(phasenet_picks)
picks
# Out:
#        station_id               phase_time  phase_score phase_type    dt  \
# 0     GE.BBJI..BH  2024-09-18T02:41:12.889        0.842          P  0.01
# 1     GE.BBJI..BH  2024-09-18T02:43:52.929        0.433          P  0.01
# 2     GE.BBJI..BH  2024-09-18T02:45:27.619        0.899          P  0.01
# 3     GE.BBJI..BH  2024-09-18T02:46:39.539        0.836          P  0.01
# 4     GE.BBJI..BH  2024-09-18T02:47:40.049        0.728          P  0.01
# ..            ...                      ...          ...        ...   ...
# 237  GE.TOLI2..BH  2024-09-18T03:21:56.669        0.505          S  0.01
# 238  GE.TOLI2..BH  2024-09-18T03:22:48.589        0.547          S  0.01
# 239  GE.TOLI2..BH  2024-09-18T03:23:40.269        0.485          S  0.01
# 240  GE.TOLI2..BH  2024-09-18T03:23:48.169        0.335          S  0.01
# 241  GE.TOLI2..BH  2024-09-18T03:32:25.809        0.323          S  0.01
#
#      phase_amplitude
# 0       5.412620e-03
# 1       6.376755e-05
# 2       1.355458e-05
# 3       1.039981e-05
# 4       3.330756e-06
# ..               ...
# 237     2.172834e-07
# 238     3.097030e-07
# 239     2.467740e-07
# 240     1.933812e-07
# 241     2.652660e-07
#
# [242 rows x 6 columns]

# %%
# Assuming 'picks' is your DataFrame
# Step 1: Filter rows where 'phase_amplitude' is NaN
nan_amplitude_rows = picks[picks['phase_amplitude'].isna()]

# Step 2: Check if 'phase_type' is 'P' for all those rows
all_nan_amplitude_are_P = (nan_amplitude_rows['phase_type'] == 'P').all()

if all_nan_amplitude_are_P:
    print("All NaN values in 'phase_amplitude' occur when 'phase_type' is 'P'")
else:
    print("There are NaN values in 'phase_amplitude' that do not occur when 'phase_type' is 'P'")
# Out:
# All NaN values in 'phase_amplitude' occur when 'phase_type' is 'P'

# %% [markdown]
# ## 7. Associate picks using GaMMA

# %%
# GAMMA_API_URL = "http://gamma.quakeflow.com"
GAMMA_API_URL = "http://34.123.47.103:8000"

# stations_json = json.loads(station_locs.to_json(orient="records"))
# stations_json = station_locs.to_dict(orient="records")
# config_gamma = {'xlim_degree': config["xlim_degree"],
#                 'ylim_degree': config["ylim_degree"],
#                 'z(km)': [0, 41],
#                 'use_amplitude': False}

# phasenet_picks = pd.DataFrame(phasenet_picks)
# phasenet_picks["id"] = phasenet_picks["station_id"]
# phasenet_picks["timestamp"] = phasenet_picks["phase_time"]
# phasenet_picks["type"] = phasenet_picks["phase_type"]
# phasenet_picks["prob"] = phasenet_picks["phase_score"]
# phasenet_picks = json.loads(phasenet_picks.to_json(orient="records"))
result = requests.post(f'{GAMMA_API_URL}/predict', json= {"picks": phasenet_picks,
                                                          "stations": stations_json,
                                                          "config": {"use_amplitude": False,
                                                                     "min_picks_per_eq": 5,
                                                                      "min_p_picks_per_eq": 0,
                                                                      "min_s_picks_per_eq": 0,
                                                                      "max_sigma11": 10.0,
                                                                      "max_sigma22": 1.0,
                                                                      "max_sigma12": 1.0,}})
result = result.json()
print(result)


# events_gamma = result["events"]
# picks_gamma = result["picks"]
# print("GaMMA catalog:")
# display(pd.DataFrame(events_gamma))
# print("GaMMA association:")
# display(pd.DataFrame(picks_gamma))
# Out:
# {'events': [{'time': '2024-09-18T03:08:31.640', 'magnitude': 999, 'sigma_time': 4.792024295546496, 'sigma_amp': 0, 'cov_time_amp': 0, 'gamma_score': 10.762634474783443, 'num_picks': 5, 'num_p_picks': 3, 'num_s_picks': 2, 'event_index': 1, 'longitude': 108.10873817472368, 'latitude': -7.457718149352783, 'depth_km': 0.0}], 'picks': [{'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:41:12.889000', 'phase_score': 0.842, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 0.005412620026618242, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:43:52.929000', 'phase_score': 0.433, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 6.37675475445576e-05, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:45:27.619000', 'phase_score': 0.899, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 1.3554576071328484e-05, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:46:39.539000', 'phase_score': 0.836, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 1.0399807251815218e-05, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:47:40.049000', 'phase_score': 0.728, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 3.3307564990536775e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:48:26.449000', 'phase_score': 0.901, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 9.718434739625081e-05, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:49:41.219000', 'phase_score': 0.825, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 2.2399112822313327e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:49:54.539000', 'phase_score': 0.332, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 3.0940354918129742e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:50:46.929000', 'phase_score': 0.757, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 1.986181359825423e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:51:25.369000', 'phase_score': 0.753, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 5.086860710434848e-07, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:51:27.099000', 'phase_score': 0.383, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 1.364043328067055e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:52:32.539000', 'phase_score': 0.839, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 9.282871928917302e-07, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:52:41.139000', 'phase_score': 0.849, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 3.218093297618907e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:53:19.139000', 'phase_score': 0.938, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 4.573756086756475e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:54:01.019000', 'phase_score': 0.929, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 3.6460057799558854e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:54:15.029000', 'phase_score': 0.911, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 2.9630234621436102e-06, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:55:08.969000', 'phase_score': 0.542, 'phase_type': 'P', 'dt': 0.01, 'phase_amplitude': 9.614198006602237e-07, 'event_index': -1, 'gamma_score': -1.0}, {'station_id': 'GE.BBJI..BH', 'phase_time': '2024-09-18T02:55:31.179000', 'phase_score': 0.9 ...

# %%
events_gamma = result["events"]
picks_gamma = result["picks"]
print("GaMMA catalog:")
display(pd.DataFrame(events_gamma))
print("GaMMA association:")
display(pd.DataFrame(picks_gamma))
# Out:
# GaMMA catalog:
#                       time  magnitude  sigma_time  sigma_amp  cov_time_amp  \
# 0  2024-09-18T03:08:31.640        999    4.792024          0             0
#
#    gamma_score  num_picks  num_p_picks  num_s_picks  event_index   longitude  \
# 0    10.762634          5            3            2            1  108.108738
#
#    latitude  depth_km
# 0 -7.457718       0.0
# GaMMA association:
#        station_id                  phase_time  phase_score phase_type    dt  \
# 0     GE.BBJI..BH  2024-09-18T02:41:12.889000        0.842          P  0.01
# 1     GE.BBJI..BH  2024-09-18T02:43:52.929000        0.433          P  0.01
# 2     GE.BBJI..BH  2024-09-18T02:45:27.619000        0.899          P  0.01
# 3     GE.BBJI..BH  2024-09-18T02:46:39.539000        0.836          P  0.01
# 4     GE.BBJI..BH  2024-09-18T02:47:40.049000        0.728          P  0.01
# ..            ...                         ...          ...        ...   ...
# 237  GE.TOLI2..BH  2024-09-18T03:21:56.669000        0.505          S  0.01
# 238  GE.TOLI2..BH  2024-09-18T03:22:48.589000        0.547          S  0.01
# 239  GE.TOLI2..BH  2024-09-18T03:23:40.269000        0.485          S  0.01
# 240  GE.TOLI2..BH  2024-09-18T03:23:48.169000        0.335          S  0.01
# 241  GE.TOLI2..BH  2024-09-18T03:32:25.809000        0.323          S  0.01
#
#      phase_amplitude  event_index  gamma_score
# 0       5.412620e-03           -1         -1.0
# 1       6.376755e-05           -1         -1.0
# 2       1.355458e-05           -1         -1.0
# 3       1.039981e-05           -1         -1.0
# 4       3.330756e-06           -1         -1.0
# ..               ...          ...          ...
# 237     2.172834e-07           -1         -1.0
# 238     3.097030e-07           -1         -1.0
# 239     2.467740e-07           -1         -1.0
# 240     1.933812e-07           -1         -1.0
# 241     2.652660e-07           -1         -1.0
#
# [242 rows x 8 columns]

# %%
phasenet_picks
# Out:
# [{'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:41:12.889',
#   'phase_score': 0.842,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 0.005412620026618242},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:43:52.929',
#   'phase_score': 0.433,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.37675475445576e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:45:27.619',
#   'phase_score': 0.899,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.3554576071328484e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:39.539',
#   'phase_score': 0.836,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0399807251815218e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:40.049',
#   'phase_score': 0.728,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.3307564990536775e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:48:26.449',
#   'phase_score': 0.901,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.718434739625081e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:41.219',
#   'phase_score': 0.825,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.2399112822313327e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:54.539',
#   'phase_score': 0.332,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.0940354918129742e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:50:46.929',
#   'phase_score': 0.757,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.986181359825423e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:25.369',
#   'phase_score': 0.753,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.086860710434848e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:27.099',
#   'phase_score': 0.383,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.364043328067055e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:32.539',
#   'phase_score': 0.839,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.282871928917302e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:41.139',
#   'phase_score': 0.849,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.218093297618907e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:53:19.139',
#   'phase_score': 0.938,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.573756086756475e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:01.019',
#   'phase_score': 0.929,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.6460057799558854e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:15.029',
#   'phase_score': 0.911,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.9630234621436102e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:08.969',
#   'phase_score': 0.542,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.614198006602237e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:31.179',
#   'phase_score': 0.924,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 7.415828804369085e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:56:46.179',
#   'phase_score': 0.878,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.270209382819303e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:56:59.749',
#   'phase_score': 0.369,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.07962704179954e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:12.889',
#   'phase_score': 0.872,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.734748118717107e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:23.079',
#   'phase_score': 0.903,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.024310543281899e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:41.739',
#   'phase_score': 0.954,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.4976864046475384e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:24.639',
#   'phase_score': 0.897,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.58664976072032e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:43.349',
#   'phase_score': 0.368,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.3000269518670393e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:59:31.769',
#   'phase_score': 0.719,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 8.113091780614923e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:07.699',
#   'phase_score': 0.933,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.890335056486947e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:48.079',
#   'phase_score': 0.957,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.302953584556235e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:12.089',
#   'phase_score': 0.855,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.50868059892673e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:38.449',
#   'phase_score': 0.423,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.614253382191237e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:50.029',
#   'phase_score': 0.482,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.174525992719282e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:04:34.649',
#   'phase_score': 0.443,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.167560803125525e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:05:24.129',
#   'phase_score': 0.969,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.046306442731293e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:06:37.379',
#   'phase_score': 0.931,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.033222012367332e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:07:51.699',
#   'phase_score': 0.514,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.22520303750207e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:23.199',
#   'phase_score': 0.906,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.73854192048384e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:44.419',
#   'phase_score': 0.725,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.620011620521836e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:11:15.419',
#   'phase_score': 0.933,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.818212917394703e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:13:03.379',
#   'phase_score': 0.953,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.262284048512811e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:13:26.899',
#   'phase_score': 0.832,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 7.007540148151747e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:14:11.289',
#   'phase_score': 0.585,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.9902263173135e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:14:46.289',
#   'phase_score': 0.952,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.2160770666014287e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:15:39.419',
#   'phase_score': 0.787,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.802792545888224e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:16:32.409',
#   'phase_score': 0.433,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.563631131939474e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:17:58.049',
#   'phase_score': 0.851,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.034023047301162e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:18:26.489',
#   'phase_score': 0.794,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.231111117609544e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:18:38.599',
#   'phase_score': 0.912,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.0519402116624406e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:19:14.369',
#   'phase_score': 0.348,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.85389080040477e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:22.969',
#   'phase_score': 0.335,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.698094133142149e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:27.019',
#   'phase_score': 0.376,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.631476369671873e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:37.979',
#   'phase_score': 0.654,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0753138894870062e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:21:22.239',
#   'phase_score': 0.959,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.900136668264167e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:23:31.379',
#   'phase_score': 0.89,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.2598981053743046e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:24:06.779',
#   'phase_score': 0.877,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.419397043875506e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:24:42.819',
#   'phase_score': 0.84,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.768475830336683e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:26:05.089',
#   'phase_score': 0.862,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.523218646885653e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:26:39.019',
#   'phase_score': 0.934,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.431036467802187e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:29:15.099',
#   'phase_score': 0.4,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.162285106052877e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:29:36.769',
#   'phase_score': 0.919,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0262301657348871e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:31:11.279',
#   'phase_score': 0.929,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.174783493406721e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:31:30.909',
#   'phase_score': 0.308,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.738500709005166e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:32:24.779',
#   'phase_score': 0.876,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.994922164769378e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:05.079',
#   'phase_score': 0.95,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.326463335426524e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:33.039',
#   'phase_score': 0.912,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 7.879752388362249e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:38:05.209',
#   'phase_score': 0.908,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.1064905720559182e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:38:58.209',
#   'phase_score': 0.378,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 5.954094035587332e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:41:16.859',
#   'phase_score': 0.762,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 0.005412620026618242},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:43:56.849',
#   'phase_score': 0.345,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.748487819801085e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:45:31.479',
#   'phase_score': 0.675,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1955237823713105e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:47.849',
#   'phase_score': 0.492,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0399807251815218e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:46:55.729',
#   'phase_score': 0.537,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.747132036049152e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:46.529',
#   'phase_score': 0.402,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.7154663914407138e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:47:55.659',
#   'phase_score': 0.667,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.773294782964513e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:48:30.529',
#   'phase_score': 0.899,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.718434739625081e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:45.149',
#   'phase_score': 0.792,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.548115389799932e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:49:58.669',
#   'phase_score': 0.498,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.779884425763157e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:50:50.699',
#   'phase_score': 0.821,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.986181359825423e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:31.219',
#   'phase_score': 0.837,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.353004790871637e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:42.289',
#   'phase_score': 0.331,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.198167751681467e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:51:54.369',
#   'phase_score': 0.347,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0836748742804048e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:36.579',
#   'phase_score': 0.76,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1247284419368953e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:52:45.259',
#   'phase_score': 0.891,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.218093297618907e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:53:23.069',
#   'phase_score': 0.896,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.573756086756475e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:04.939',
#   'phase_score': 0.876,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.6460057799558854e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:54:18.829',
#   'phase_score': 0.901,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.9630234621436102e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:12.679',
#   'phase_score': 0.812,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.614198006602237e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:35.099',
#   'phase_score': 0.754,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.560805102002632e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:55:52.669',
#   'phase_score': 0.616,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.038408741915191e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:56:50.299',
#   'phase_score': 0.86,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.270209382819303e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:04.679',
#   'phase_score': 0.481,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.07962704179954e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:17.019',
#   'phase_score': 0.723,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.734748118717107e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:27.199',
#   'phase_score': 0.806,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.024310543281899e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:57:45.829',
#   'phase_score': 0.855,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.4976864046475384e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:28.789',
#   'phase_score': 0.821,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.58664976072032e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:58:47.239',
#   'phase_score': 0.411,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.3000269518670393e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T02:59:35.399',
#   'phase_score': 0.736,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.347796102090797e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:00:41.639',
#   'phase_score': 0.605,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.853510742781509e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:11.819',
#   'phase_score': 0.834,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.890335056486947e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:36.779',
#   'phase_score': 0.768,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0529754490562482e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:01:51.989',
#   'phase_score': 0.925,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.302953584556235e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:02:32.499',
#   'phase_score': 0.649,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.139616743894294e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:02:48.689',
#   'phase_score': 0.542,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.605399226420559e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:16.219',
#   'phase_score': 0.743,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.50868059892673e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:43.399',
#   'phase_score': 0.863,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.379987442211132e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:03:52.509',
#   'phase_score': 0.807,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.174525992719282e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:04:05.569',
#   'phase_score': 0.351,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.006190235690156e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:05:27.989',
#   'phase_score': 0.87,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.046306442731293e-05},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:06:41.499',
#   'phase_score': 0.903,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.033222012367332e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:07:55.479',
#   'phase_score': 0.82,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.22520303750207e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:26.979',
#   'phase_score': 0.852,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.73854192048384e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:46.449',
#   'phase_score': 0.436,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.620011620521836e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:08:59.789',
#   'phase_score': 0.504,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.7661628817222663e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:09:13.069',
#   'phase_score': 0.553,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.714769930724287e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:10:22.689',
#   'phase_score': 0.358,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.4472716353993746e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:11:19.459',
#   'phase_score': 0.773,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.818212917394703e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:12:22.289',
#   'phase_score': 0.462,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.4180399666183803e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:12:41.049',
#   'phase_score': 0.634,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.613386070355773e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:13:07.099',
#   'phase_score': 0.856,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.262284048512811e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:13:30.939',
#   'phase_score': 0.61,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.007540148151747e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:14:15.399',
#   'phase_score': 0.857,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.396651883733284e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:14:20.059',
#   'phase_score': 0.483,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.9902263173135e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:14:50.219',
#   'phase_score': 0.734,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.2160770666014287e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:15:43.279',
#   'phase_score': 0.86,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.6601240910604247e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:16:37.159',
#   'phase_score': 0.826,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.563631131939474e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:18:01.919',
#   'phase_score': 0.768,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.034023047301162e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:18:30.459',
#   'phase_score': 0.717,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.922537292870402e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:18:42.639',
#   'phase_score': 0.934,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.0519402116624406e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:19:18.459',
#   'phase_score': 0.785,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.85389080040477e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:26.909',
#   'phase_score': 0.358,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.631476369671873e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:33.159',
#   'phase_score': 0.794,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.414729571384669e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:20:41.799',
#   'phase_score': 0.483,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0753138894870062e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:21:26.299',
#   'phase_score': 0.818,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.900136668264167e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:23:35.239',
#   'phase_score': 0.798,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.2598981053743046e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:24:10.659',
#   'phase_score': 0.72,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.419397043875506e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:24:46.779',
#   'phase_score': 0.823,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.768475830336683e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:25:08.419',
#   'phase_score': 0.744,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.01057491217216e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:26:09.189',
#   'phase_score': 0.856,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.523218646885653e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:26:43.049',
#   'phase_score': 0.797,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.431036467802187e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:29:05.479',
#   'phase_score': 0.784,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.286648677658377e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:29:18.499',
#   'phase_score': 0.816,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.162285106052877e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:29:41.189',
#   'phase_score': 0.637,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.0262301657348871e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:30:47.599',
#   'phase_score': 0.822,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.538158068749908e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:31:15.099',
#   'phase_score': 0.764,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.174783493406721e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:32:28.569',
#   'phase_score': 0.814,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.994922164769378e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:34:35.649',
#   'phase_score': 0.399,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 4.395471080442803e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:08.979',
#   'phase_score': 0.772,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 6.326463335426524e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:36:36.899',
#   'phase_score': 0.648,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.879752388362249e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:37:54.849',
#   'phase_score': 0.332,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.301653231981618e-07},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:38:09.159',
#   'phase_score': 0.908,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1064905720559182e-06},
#  {'station_id': 'GE.BBJI..BH',
#   'phase_time': '2024-09-18T03:39:01.979',
#   'phase_score': 0.851,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.954094035587332e-07},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.528,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.343380169302691e-06},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:01:44.409',
#   'phase_score': 0.465,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.113783562497701e-06},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:12:02.189',
#   'phase_score': 0.438,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.544241947878618e-06},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:13:08.789',
#   'phase_score': 0.487,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.7309757822658867e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:22:40.209',
#   'phase_score': 0.324,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 8.014098966668826e-06},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:22:48.059',
#   'phase_score': 0.301,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.2582251656567678e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:23:34.969',
#   'phase_score': 0.568,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0773140274977777e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:23:43.549',
#   'phase_score': 0.466,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.029274153552251e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:23:52.749',
#   'phase_score': 0.566,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.5015044482424855e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:26:04.649',
#   'phase_score': 0.359,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.4045325769984629e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:30:17.589',
#   'phase_score': 0.467,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.4011912753630895e-05},
#  {'station_id': 'GE.BKB..BH',
#   'phase_time': '2024-09-18T03:23:46.269',
#   'phase_score': 0.395,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.5015044482424855e-05},
#  {'station_id': 'GE.BNDI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.368,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.367564542917535e-06},
#  {'station_id': 'GE.FAKI..BH',
#   'phase_time': '2024-09-18T02:59:36.339',
#   'phase_score': 0.874,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.628111014426395e-07},
#  {'station_id': 'GE.FAKI..BH',
#   'phase_time': '2024-09-18T03:26:46.809',
#   'phase_score': 0.568,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.396637566766003e-07},
#  {'station_id': 'GE.FAKI..BH',
#   'phase_time': '2024-09-18T03:00:01.149',
#   'phase_score': 0.319,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 9.106353218157892e-07},
#  {'station_id': 'GE.FAKI..BH',
#   'phase_time': '2024-09-18T03:16:19.969',
#   'phase_score': 0.348,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.176192416911363e-07},
#  {'station_id': 'GE.FAKI..BH',
#   'phase_time': '2024-09-18T03:26:49.389',
#   'phase_score': 0.369,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.396637566766003e-07},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:07:46.249',
#   'phase_score': 0.542,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.878062554780627e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:08:51.009',
#   'phase_score': 0.504,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.3018603769742185e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:09:00.929',
#   'phase_score': 0.606,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.9937834824522724e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T02:46:04.689',
#   'phase_score': 0.333,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.9973278995166766e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T02:50:13.809',
#   'phase_score': 0.49,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.0275316476036096e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T02:52:29.489',
#   'phase_score': 0.377,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.4402753499307437e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T02:53:05.929',
#   'phase_score': 0.344,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.109831823167042e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T02:57:07.509',
#   'phase_score': 0.584,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.533851435757242e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:03:31.169',
#   'phase_score': 0.61,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.192210442648502e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:08:43.079',
#   'phase_score': 0.568,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.428015704936115e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:08:54.139',
#   'phase_score': 0.813,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.488039172021672e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:22:57.309',
#   'phase_score': 0.471,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.2114668354333844e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:23:43.709',
#   'phase_score': 0.565,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.7469397991808364e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:31:43.489',
#   'phase_score': 0.451,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1949916824960383e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:31:47.869',
#   'phase_score': 0.347,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.13032490137266e-06},
#  {'station_id': 'GE.GSI..BH',
#   'phase_time': '2024-09-18T03:37:55.169',
#   'phase_score': 0.423,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.2506603727379115e-06},
#  {'station_id': 'GE.JAGI..BH',
#   'phase_time': '2024-09-18T02:42:45.149',
#   'phase_score': 0.316,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.426991841275594e-06},
#  {'station_id': 'GE.JAGI..BH',
#   'phase_time': '2024-09-18T02:57:52.529',
#   'phase_score': 0.323,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 5.968870482320199e-07},
#  {'station_id': 'GE.JAGI..BH',
#   'phase_time': '2024-09-18T03:22:58.099',
#   'phase_score': 0.386,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 7.387469622699427e-07},
#  {'station_id': 'GE.LHMI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.441,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 4.632432137441356e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T02:41:07.319',
#   'phase_score': 0.445,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 6.395850391527347e-07},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T02:41:20.469',
#   'phase_score': 0.309,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.034264300869836e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T02:42:59.389',
#   'phase_score': 0.336,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.5487714790651808e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:06:59.579',
#   'phase_score': 0.313,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.385218522249488e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:08:15.949',
#   'phase_score': 0.629,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.5160312614170834e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:12:55.729',
#   'phase_score': 0.457,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.0328257076253067e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:13:29.269',
#   'phase_score': 0.332,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.8072014427161776e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:13:49.139',
#   'phase_score': 0.331,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.1612726161256433e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:22:00.139',
#   'phase_score': 0.476,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.0741852040373487e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:30:05.179',
#   'phase_score': 0.776,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 8.152322266141709e-07},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:34:12.269',
#   'phase_score': 0.626,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.7115303307946306e-06},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:38:07.469',
#   'phase_score': 0.642,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.772809335117927e-07},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T03:40:31.709',
#   'phase_score': 0.443,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 9.102357694246166e-07},
#  {'station_id': 'GE.LUWI..BH',
#   'phase_time': '2024-09-18T02:47:53.389',
#   'phase_score': 0.421,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.284898189624073e-06},
#  {'station_id': 'GE.MMRI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.443,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.5020269756860216e-06},
#  {'station_id': 'GE.MMRI..BH',
#   'phase_time': '2024-09-18T02:42:49.929',
#   'phase_score': 0.365,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.4802601526753278e-06},
#  {'station_id': 'GE.MMRI..BH',
#   'phase_time': '2024-09-18T03:09:47.749',
#   'phase_score': 0.347,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.938732793860254e-06},
#  {'station_id': 'GE.PLAI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.471,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.747786525565289e-09},
#  {'station_id': 'GE.PMBI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.473,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 8.032841833482962e-06},
#  {'station_id': 'GE.SMRI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.594,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.6047650888140197e-06},
#  {'station_id': 'GE.SMRI..BH',
#   'phase_time': '2024-09-18T03:14:25.729',
#   'phase_score': 0.348,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.3487413020338863e-06},
#  {'station_id': 'GE.SMRI..BH',
#   'phase_time': '2024-09-18T03:33:09.549',
#   'phase_score': 0.547,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.9601615096908063e-06},
#  {'station_id': 'GE.SOEI..BH',
#   'phase_time': '2024-09-18T02:51:13.869',
#   'phase_score': 0.378,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.6836485176318092e-06},
#  {'station_id': 'GE.SOEI..BH',
#   'phase_time': '2024-09-18T03:40:10.219',
#   'phase_score': 0.431,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.155824970235699e-06},
#  {'station_id': 'GE.SOEI..BH',
#   'phase_time': '2024-09-18T02:43:26.769',
#   'phase_score': 0.477,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.679423459994723e-06},
#  {'station_id': 'GE.TNTI..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.713,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.441016706849041e-06},
#  {'station_id': 'GE.TNTI..BH',
#   'phase_time': '2024-09-18T02:51:31.389',
#   'phase_score': 0.453,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.3872360113964533e-06},
#  {'station_id': 'GE.TNTI..BH',
#   'phase_time': '2024-09-18T03:04:58.089',
#   'phase_score': 0.342,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.5256313190548099e-06},
#  {'station_id': 'GE.TNTI..BH',
#   'phase_time': '2024-09-18T03:39:13.319',
#   'phase_score': 0.405,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.900383267638972e-06},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:41:06.679',
#   'phase_score': 0.314,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 1.9070550649757934e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:53:13.619',
#   'phase_score': 0.575,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.7987400130768947e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:56:30.059',
#   'phase_score': 0.403,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.1116414927746519e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:00:40.139',
#   'phase_score': 0.379,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.1638705050008866e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:04:54.049',
#   'phase_score': 0.558,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.194143403106864e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:06.009',
#   'phase_score': 0.609,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 3.146691938127333e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:42.949',
#   'phase_score': 0.31,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.961456289085618e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:48.099',
#   'phase_score': 0.697,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.588195968655782e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:38:39.859',
#   'phase_score': 0.317,
#   'phase_type': 'P',
#   'dt': 0.01,
#   'phase_amplitude': 2.592032330994698e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:49:44.689',
#   'phase_score': 0.411,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.3119167142103834e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T02:59:13.579',
#   'phase_score': 0.405,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.587345531741448e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:01:59.559',
#   'phase_score': 0.361,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.4192712544390815e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:04:58.759',
#   'phase_score': 0.766,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.194143403106864e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:09:47.719',
#   'phase_score': 0.546,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.961456289085618e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:11:43.249',
#   'phase_score': 0.386,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.1181214176758658e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:11:43.889',
#   'phase_score': 0.462,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.479090426277253e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:12:52.049',
#   'phase_score': 0.648,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.2371450825175998e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:08.909',
#   'phase_score': 0.689,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.5661390168352227e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:14.449',
#   'phase_score': 0.306,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.453284366765729e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:16:51.859',
#   'phase_score': 0.648,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.5939044689948787e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:21:56.669',
#   'phase_score': 0.505,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.1728338595039531e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:22:48.589',
#   'phase_score': 0.547,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 3.0970304010224936e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:23:40.269',
#   'phase_score': 0.485,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.4677399323991267e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:23:48.169',
#   'phase_score': 0.335,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 1.93381154645067e-07},
#  {'station_id': 'GE.TOLI2..BH',
#   'phase_time': '2024-09-18T03:32:25.809',
#   'phase_score': 0.323,
#   'phase_type': 'S',
#   'dt': 0.01,
#   'phase_amplitude': 2.6526601004661643e-07}]

# %% [markdown]
# ## Optional: Run PhaseNet and GaMMA together

# %%
# PHASENET_API_URL = "http://test.quakeflow.com:8001"

# req = {"id": meta["station_id"],
#        "timestamp": meta["t0"],
#        "vec": meta["data"].squeeze().tolist(),
#        "stations": stations_json,
#        "config": config_gamma}

# resp = requests.post(f'{PHASENET_API_URL}/predict_phasenet2gamma2ui', json=req)
# print(resp.json())
# result = resp.json()
# catalog_gamma = result["catalog"]
# picks_gamma = result["picks"]
# print("Catalog:")
# display(pd.DataFrame(catalog_gamma))
# print("Association:")
# display(pd.DataFrame(picks_gamma))

# %% [markdown]
# ## Compare with official catalog

# %%
event = events[0]
print(event.origins[0])
print(event.magnitudes[0])
# Out:
# Origin
# 	   resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=50748472")
# 	          time: UTCDateTime(2024, 9, 18, 2, 41, 6, 667000)
# 	     longitude: 107.5693
# 	      latitude: -7.2397
# 	         depth: 10000.0
# 	 creation_info: CreationInfo(author='us,usauto')
# Magnitude
# 	    resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=216566657")
# 	            mag: 5.1
# 	 magnitude_type: 'Mww'
# 	  creation_info: CreationInfo(author='us')
